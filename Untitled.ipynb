# %%
import pandas as pd
import json
from pprint import pprint

# %%
df = pd.read_csv('1.csv')
val = json.loads(df.to_json(orient="index"))

val
# Out:
# {'0': {'phone': 84242411279,
#   'visitid': 3044649568,
#   'snils': 6386692505,
#   'visit_date': '2022-01-01'},
#  '1': {'phone': 89004281911,
#   'visitid': 3044653016,
#   'snils': 18795120009,
#   'visit_date': '2022-01-01'},
#  '2': {'phone': 89006605105,
#   'visitid': 3044408950,
#   'snils': 13939011972,
#   'visit_date': '2022-01-01'},
#  '3': {'phone': 89137028112,
#   'visitid': 3044480118,
#   'snils': 6386439897,
#   'visit_date': '2022-01-01'},
#  '4': {'phone': 89144080116,
#   'visitid': 3044580126,
#   'snils': 6984876850,
#   'visit_date': '2022-01-01'},
#  '5': {'phone': 89146402317,
#   'visitid': 3044518427,
#   'snils': 16446950392,
#   'visit_date': '2022-01-01'},
#  '6': {'phone': 89146411293,
#   'visitid': 3044492724,
#   'snils': 11597230259,
#   'visit_date': '2022-01-01'},
#  '7': {'phone': 89146689436,
#   'visitid': 3044439888,
#   'snils': 16720452355,
#   'visit_date': '2022-01-01'},
#  '8': {'phone': 89147459019,
#   'visitid': 3044506712,
# ...
